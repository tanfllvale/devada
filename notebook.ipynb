# %%
import pandas as pd

# %%
df = pd.read_csv("master_merged_data.csv")
df.head()
# Out:
#          date  fire_frp_sum  fire_frp_sum_tomorrow  wind_speed   wind_dir  \
# 0  2025-01-01        1399.4                 4478.8    3.885665  327.33905
# 1  2025-01-02        4478.8                  886.1    3.438895  328.81516
# 2  2025-01-03         886.1                 3397.8    9.292255  180.32007
# 3  2025-01-04        3397.8                 3088.0   10.182337  114.59477
# 4  2025-01-05        3088.0                  997.6    5.318383  351.86996
#
#         pm25   latitude   longitude
# 0  35.372222  34.086631 -118.237153
# 1  18.800000  34.111249 -118.244422
# 2  19.581818  34.111249 -118.244422
# 3  21.906667  34.095036 -118.241187
# 4  13.633333  34.090283 -118.240779
